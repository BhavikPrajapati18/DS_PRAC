# %% [markdown]
# <a href="https://colab.research.google.com/github/BhavikPrajapati18/DS_PRAC/blob/main/Ques2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans

iris = load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)

inertia = []
K_range = range(1, 11)

for k in K_range:
    km = KMeans(n_clusters=k, random_state=42)
    km.fit(X)
    inertia.append(km.inertia_)

plt.figure(figsize=(8, 4))
plt.plot(K_range, inertia, marker='o')
plt.title('Elbow Method For Optimal K')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Inertia (Error)')
plt.grid(True)
plt.show()

kmeans = KMeans(n_clusters=3, random_state=42)
X['cluster'] = kmeans.fit_predict(X)

plt.figure(figsize=(8, 6))
plt.scatter(X.iloc[:, 0], X.iloc[:, 1], c=X['cluster'], cmap='viridis')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('K-Means Clustering (Iris Dataset)')
plt.grid(True)
plt.show()

print("Cluster Centers:\n")
centers = pd.DataFrame(kmeans.cluster_centers_, columns=iris.feature_names)
print(centers)

print("\nNumber of data points in each cluster:")
print(X['cluster'].value_counts())
# Out:
# Cluster Centers:
#
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0           6.853846          3.076923           5.715385          2.053846
# 1           5.006000          3.428000           1.462000          0.246000
# 2           5.883607          2.740984           4.388525          1.434426
#
# Number of data points in each cluster:
# cluster
# 2    61
# 1    50
# 0    39
# Name: count, dtype: int64

# %% [markdown]
# # New section
